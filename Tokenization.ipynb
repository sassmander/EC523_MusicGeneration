# %%
# !pip install miditok
# !pip install tokenizers
# !pip install setuptools_rust
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import miditok
import miditoolkit
from miditok import *
import json
import numpy as np

# %%
token = REMI()
token.load_params('/content/drive/Shareddrives/EC523_Project/CodeWorkspace/REMItokenizer.json')

# %%
vocab = token.vocab
# Opening JSON file
f = open('/content/drive/Shareddrives/EC523_Project/CodeWorkspace/tokens_noBPE/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--3.json')
# returns JSON object as a dictionary
data = json.load(f)
data = data['ids'][0]
key_list = list(vocab.keys())
val_list = list(vocab.values())
for i in data[:200]:
  position = val_list.index(i)
  print(i,key_list[position])
# Out:
# 4 Bar_None
# 205 Position_16
# 22 Pitch_38
# 108 Velocity_63
# 127 Duration_0.3.8
# 206 Position_17
# 25 Pitch_41
# 109 Velocity_67
# 127 Duration_0.3.8
# 207 Position_18
# 29 Pitch_45
# 110 Velocity_71
# 126 Duration_0.2.8
# 34 Pitch_50
# 113 Velocity_83
# 126 Duration_0.2.8
# 208 Position_19
# 46 Pitch_62
# 109 Velocity_67
# 125 Duration_0.1.8
# 49 Pitch_65
# 110 Velocity_71
# 126 Duration_0.2.8
# 209 Position_20
# 53 Pitch_69
# 111 Velocity_75
# 125 Duration_0.1.8
# 58 Pitch_74
# 115 Velocity_91
# 125 Duration_0.1.8
# 212 Position_23
# 58 Pitch_74
# 114 Velocity_87
# 125 Duration_0.1.8
# 215 Position_26
# 34 Pitch_50
# 110 Velocity_71
# 126 Duration_0.2.8
# 37 Pitch_53
# 111 Velocity_75
# 126 Duration_0.2.8
# 46 Pitch_62
# 113 Velocity_83
# 126 Duration_0.2.8
# 58 Pitch_74
# 115 Velocity_91
# 127 Duration_0.3.8
# 218 Position_29
# 54 Pitch_70
# 112 Velocity_79
# 125 Duration_0.1.8
# 66 Pitch_82
# 113 Velocity_83
# 125 Duration_0.1.8
# 220 Position_31
# 54 Pitch_70
# ...

# %%
# list out keys and values separately

for i in range(0,2560,128):
  tok = data[i]
  position = val_list.index(tok)
  print(tok,key_list[position])
# Out:
# 4 Bar_None
# 201 Position_12
# 110 Velocity_71
# 109 Velocity_67
# 34 Pitch_50
# 4 Bar_None
# 107 Velocity_59
# 51 Pitch_67
# 114 Velocity_87
# 126 Duration_0.2.8
# 192 Position_3
# 51 Pitch_67
# 116 Velocity_95
# 25 Pitch_41
# 115 Velocity_91
# 201 Position_12
# 125 Duration_0.1.8
# 51 Pitch_67
# 108 Velocity_63
# 48 Pitch_64
